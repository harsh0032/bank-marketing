# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\Nehal\\OneDrive\\Documents\\2-Bank-marketing campaign.csv")

# %%
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
df.tail()
# Out:
#        age           job   marital  education default  balance housing loan  \
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# 45206   cellular   17   nov       977         3     -1         0  unknown  yes
# 45207   cellular   17   nov       456         2     -1         0  unknown  yes
# 45208   cellular   17   nov      1127         5    184         3  success  yes
# 45209  telephone   17   nov       508         4     -1         0  unknown   no
# 45210   cellular   17   nov       361         2    188        11    other   no

# %%
#This data set is about wether the customers are going to make a term deposit in bank depending on various attributes.
#Target variable: y (Does the customer make a term deposit-"yes"/"No")
#Data visulaization has been carried to know the relationship of both continuous and categorical variables with eachother and especially with the target variable (y).

# %%
df.shape    #There are 45211 rows(entry of clients) and 17 columns (variables)
# Out:
# (45211, 17)

# %%
df.isnull().sum()                         #Hence,there is no null value in this data
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
plt.figure(figsize=(15,15))
sns.countplot(x='job',data=df)             #There are highest number of clients in blue-collar job.
plt.show()

# %%
plt.figure(figsize=(4,4))
sns.countplot(x='marital',data=df)        #Majority of clients are married
plt.show()

# %%
plt.figure(figsize=(4,4))
sns.countplot(x='education',data=df)              #Majority of client have uptill secondary education.
plt.show()

# %%
plt.figure(figsize=(4,4))
sns.countplot(x='default',data=df)                 #Majority of clients have credit in default
plt.show()

# %%
plt.figure(figsize=(4,4))
sns.countplot(x='housing',data=df)              #Majority of clients have housing loan 
plt.show()

# %%
plt.figure(figsize=(4,4))
sns.countplot(x='loan',data=df)        #Majority of clients gave personal loan.
plt.show()

# %%
plt.figure(figsize=(4,4))
sns.countplot(x='contact',data=df)      #In the case of majority of clients, the type of communication was cellular contact.
plt.show()

# %%
plt.figure(figsize=(15,15))
sns.distplot(df['day'], kde=True, bins=20)       #Majority of contact were made on day 20
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(15,15))
sns.distplot(df['age'], kde=True, bins=20)     #Highest number of clients are there in age group 20-40.    
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(4,4))
sns.countplot(x='poutcome',data=df)          #Majority of outcomes of previous campaign is unknown.
plt.show()

# %%
plt.figure(figsize=(4,4))
sns.countplot(x='y',data=df)     #Majority of clients didnot make a deposit.
plt.show()

# %%
#Boxplot
sns.boxplot(x='marital',y='age',data=df)     
#Median age of married, single and divorced are approximately 43,34 and 45 respectively.
#In  married, single and divorced status 75% of clients are approximately below 51, 46, and 55 of age respectively.
# Out:
# <AxesSubplot:xlabel='marital', ylabel='age'>

# %%
plt.figure(figsize=(15,15))
sns.boxplot(x='job',y='age',data=df)        
#The highest median age of clients is in the retired category and the lowest median age of clients lies in student category.
# Out:
# <AxesSubplot:xlabel='job', ylabel='age'>

# %%
sns.barplot(x='education',y='age',data=df)
#Primary category of education has the highest mean age and tertiary has the lowest mean age of clients.
# Out:
# <AxesSubplot:xlabel='education', ylabel='age'>

# %%
sns.barplot(x='housing',y='age',data=df)
#Clients who haven't taken the housing loan have higher mean age.
# Out:
# <AxesSubplot:xlabel='housing', ylabel='age'>

# %%
sns.barplot(x='y',y='balance',data=df)
#Mean balance is more in case of clients who said yes to make a deposit.
# Out:
# <AxesSubplot:xlabel='y', ylabel='balance'>

# %%
sns.barplot(x='loan',y='age',data=df)
#The mean age of clients who haven't taken a personal loan are higher as compared to who have taken the loan.
# Out:
# <AxesSubplot:xlabel='loan', ylabel='age'>

# %%
sns.barplot(x='poutcome',y='age',data=df)
#The mean age is highest in the case of clients of successful outcome of previous campaign.
# Out:
# <AxesSubplot:xlabel='poutcome', ylabel='age'>

# %%
sns.boxplot(x='y',y='age',data=df)                
#The median age for both yes and no is approximately same. 75% of clients who wil make a term deposit are below the age of 50.
# Out:
# <AxesSubplot:xlabel='y', ylabel='age'>

# %%
sns.violinplot(x='y',y='age',data=df)         
#As the density of clients in age range of 35-40 is more in case of "No" as compared to "Yes" outcome.
# Out:
# <AxesSubplot:xlabel='y', ylabel='age'>

# %%
sns.barplot(x='y',y='duration',data=df)                 
#This indicates that higher the mean duration of contact with the client, higher is the chances for the client to say yes to make a deposit.
# Out:
# <AxesSubplot:xlabel='y', ylabel='duration'>

# %%
sns.barplot(x='y',y='campaign',data=df)
#The mean number of contact perfomred during the campaign was higher, in case where there was no term deposity made by the client.
# Out:
# <AxesSubplot:xlabel='y', ylabel='campaign'>

# %%
sns.barplot(x='y',y='age',data=df)
#The mean age of clients was higher who made a term deposit.
# Out:
# <AxesSubplot:xlabel='y', ylabel='age'>

# %%
sns.barplot(x='y',y='age',data=df, hue='education')
#The mean age of the clients (having a primary education) was highest who made a term deposit.
# Out:
# <AxesSubplot:xlabel='y', ylabel='age'>

# %%
sns.barplot(x='y',y='age',data=df, hue='marital')
#The mean age of the clients (Divorced) was the highest who made the term deposit.
# Out:
# <AxesSubplot:xlabel='y', ylabel='age'>

# %%
plt.figure(figsize=(10,10))
sns.barplot(x='y',y='age',data=df, hue='month')
#With outcome of term deposit as yes, the highest mean age of the clients was in the month of october.
# Out:
# <AxesSubplot:xlabel='y', ylabel='age'>

# %%
sns.barplot(x='y',y='age',data=df, hue='housing')
#the highest mean age of clients was in the case of clients (who have taken housing loan) who said yes to make term deposit.
# Out:
# <AxesSubplot:xlabel='y', ylabel='age'>

# %%
sns.barplot(x='y',y='age',data=df, hue='loan')
#The mean age of clients was highest in case of clients (who have taken a persinal loan) and said yes to make a term deposit.
# Out:
# <AxesSubplot:xlabel='y', ylabel='age'>

# %%
sns.barplot(x='y',y='age',data=df, hue='contact')
#The mean age was highest in case of clients who said yes to make a term deposit and were contacted through telephone.
# Out:
# <AxesSubplot:xlabel='y', ylabel='age'>

# %%
sns.barplot(x='y',y='age',data=df, hue='job')
#The mean age was highest in case of the clients who siad yes to make a deposit belonging to retired category.
# Out:
# <AxesSubplot:xlabel='y', ylabel='age'>

# %%
sns.barplot(x='y',y='campaign',data=df, hue='marital')
#The mean number contacts made during a campaign was highest in case of clients (married) who siad no to make a term deposit.
# Out:
# <AxesSubplot:xlabel='y', ylabel='campaign'>

# %%
sns.barplot(x='y',y='campaign',data=df, hue='education')
#The mean number of contacts made during the campaign was highest in the case of clients in the case where clients said yes to make a deposit was highest in case of clients having uptill the primary education.
# Out:
# <AxesSubplot:xlabel='y', ylabel='campaign'>

# %%
sns.barplot(x='y',y='campaign',data=df, hue='housing')
#The mean number of contacts made during the campaign was highest in the case of clients (having the housing loan) who said no to make a term deposit.
# Out:
# <AxesSubplot:xlabel='y', ylabel='campaign'>

# %%
sns.barplot(x='y',y='campaign',data=df, hue='loan')
#The mean number of contacts made during the campaign was highest in the case of clientwas highest in the case of clients (having the personal loan) who said no to make a term deposit.
# Out:
# <AxesSubplot:xlabel='y', ylabel='campaign'>

# %%
sns.barplot(x='y',y='campaign',data=df, hue='contact')
#The mean number of contacts made during the campaign was highest in the case of clients (who were contacted through telephone) who said no to make a term deposit.
# Out:
# <AxesSubplot:xlabel='y', ylabel='campaign'>

# %%
plt.figure(figsize=(10,10))
sns.barplot(x='y',y='campaign',data=df, hue='month')    
#The mean number of contacts made during the campaign was highest in the case of clients (in month of august) who said no to make a term deposit.
# Out:
# <AxesSubplot:xlabel='y', ylabel='campaign'>

# %%
data=df.select_dtypes(include=['float64','int64'])

# %%
data
# Out:
#        age  balance  day  duration  campaign  pdays  previous
# 0       58     2143    5       261         1     -1         0
# 1       44       29    5       151         1     -1         0
# 2       33        2    5        76         1     -1         0
# 3       47     1506    5        92         1     -1         0
# 4       33        1    5       198         1     -1         0
# ...    ...      ...  ...       ...       ...    ...       ...
# 45206   51      825   17       977         3     -1         0
# 45207   71     1729   17       456         2     -1         0
# 45208   72     5715   17      1127         5    184         3
# 45209   57      668   17       508         4     -1         0
# 45210   37     2971   17       361         2    188        11
#
# [45211 rows x 7 columns]

# %%
data.dtypes
# Out:
# age         int64
# balance     int64
# day         int64
# duration    int64
# campaign    int64
# pdays       int64
# previous    int64
# dtype: object

# %%
plt.figure(figsize=(10,8))
df1=df.pivot_table(index='job',columns='y',values='age')
sns.heatmap(df1,linewidth=1)
#Highest age range was found in the case of outcome 'yes' belonging to job category 'reitred'.
# Out:
# <AxesSubplot:xlabel='y', ylabel='job'>

# %%
plt.figure(figsize=(10,8))
df3=df.pivot_table(index='education',columns='y',values='age')
sns.heatmap(df3,linewidth=1)
#Highest age values was found in the outcome 'yes having education upto primary'.
# Out:
# <AxesSubplot:xlabel='y', ylabel='education'>

# %%
df6=df.pivot_table(index='contact',columns='y',values='age')
sns.heatmap(df6,linewidth=1)
#Highest age values found in outcome 'yes' who were contacted through telephone.
# Out:
# <AxesSubplot:xlabel='y', ylabel='contact'>

# %%
plt.figure(figsize=(10,8))
df8=df.pivot_table(index='job',columns='y',values='duration')
sns.heatmap(df8,linewidth=1)
#The highest duration values were found in outcome'yes' in case of clients belonging to blue-collar job category .
# Out:
# <AxesSubplot:xlabel='y', ylabel='job'>

# %%
plt.figure(figsize=(10,8))
df9=df.pivot_table(index='education',columns='y',values='duration')
sns.heatmap(df9,linewidth=1)
#Highest duration values were found in outcome 'yes' of clients having education uptill primary.
# Out:
# <AxesSubplot:xlabel='y', ylabel='education'>

# %%
plt.figure(figsize=(15,15))
sns.relplot(x='duration', y='age',hue='job',kind='scatter',cmap="Winter",data=df)
#Mostly all the job category clients lie in the time duration of 0-2000 except reitired clients which mostly lie in the range of 0-1000.

# %%
plt.figure(figsize=(15,15))
sns.stripplot(x='education', y='age', data=df, jitter=True)
#Clients in the category of secondary and primary education cover wider range of the age.
# Out:
# <AxesSubplot:xlabel='education', ylabel='age'>

# %%
plt.figure(figsize=(15,15))
sns.stripplot(x='job', y='duration', data=df, jitter=True)
#Technician job category cover wider range over duration duration.
# Out:
# <AxesSubplot:xlabel='job', ylabel='duration'>

# %%
plt.figure(figsize=(15,15))
sns.stripplot(x='marital', y='duration', data=df, jitter=True)
#married people are covering wider range of time duration of contact.
# Out:
# <AxesSubplot:xlabel='marital', ylabel='duration'>

# %%
plt.figure(figsize=(15,15))
sns.stripplot(x='education', y='duration', data=df, jitter=True)
#Clients having upto tertiary education cover wider range on duration.
# Out:
# <AxesSubplot:xlabel='education', ylabel='duration'>

# %%
df.y.value_counts()
# Out:
# no     39922
# yes     5289
# Name: y, dtype: int64

# %%
pd.get_dummies('y')
# Out:
#    y
# 0  1

# %%
df.y=df.y.map({'no':0,'yes':1})

# %%
data=df.select_dtypes(include=['float64','int64'])

# %%
data
# Out:
#        age  balance  day  duration  campaign  pdays  previous  y
# 0       58     2143    5       261         1     -1         0  0
# 1       44       29    5       151         1     -1         0  0
# 2       33        2    5        76         1     -1         0  0
# 3       47     1506    5        92         1     -1         0  0
# 4       33        1    5       198         1     -1         0  0
# ...    ...      ...  ...       ...       ...    ...       ... ..
# 45206   51      825   17       977         3     -1         0  1
# 45207   71     1729   17       456         2     -1         0  1
# 45208   72     5715   17      1127         5    184         3  1
# 45209   57      668   17       508         4     -1         0  0
# 45210   37     2971   17       361         2    188        11  0
#
# [45211 rows x 8 columns]

# %%
plt.figure(figsize=(10,8))
pd.plotting.parallel_coordinates(data,class_column='y',color=('red','blue'))
#This plot indicates the spread of output (y) vividly in respect to the balance.
# Out:
# <AxesSubplot:>
